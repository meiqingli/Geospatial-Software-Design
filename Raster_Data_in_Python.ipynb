# %% [markdown]
# <a href="https://colab.research.google.com/github/meiqingli/Geospatial-Software-Design/blob/master/Raster_Data_in_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Work with raster data in Python
#
#
# *   Python library: `rasterio` [Python Quickstart](https://rasterio.readthedocs.io/en/stable/quickstart.html#id2)
# *   Data sources:
#   *   [The USGS National Data Viewer](https://www.usgs.gov/tools/national-map-viewer)
#   *   [The USGS Earth Explorer](https://earthexplorer.usgs.gov/)

# %%
import os

if os.path.exists('/content/'):
    from google.colab import drive
    import os
    drive.mount('/content/drive')
    os.chdir('/content/drive/MyDrive/Colab Notebooks')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
pip install rasterio

# %%
import rasterio
from rasterio.plot import show

# %%
dataset = rasterio.open('Raster image/m_3712214_ne_10_060_20220518.tif')

# %%
show(dataset)
# Out:
# <Axes: >

# %% [markdown]
# https://earthexplorer.usgs.gov/scene/metadata/full/5e83a340bf820c39/3230321/

# %%
# number of bands
dataset.count
# Out:
# 4

# %%
dataset.width
# Out:
# 9920

# %%
dataset.height
# Out:
# 12290

# %%
dataset.bounds
# Out:
# BoundingBox(left=560262.0, bottom=4185036.0, right=566214.0, top=4192410.0)

# %%
dataset.crs
# Out:
# CRS.from_epsg(26910)

# %% [markdown]
# EPSG:26910
# NAD83/UTM zone 10N
# https://epsg.io/26910

# %%
# red, green, blue, and near infrared bands
dataset.indexes
# Out:
# (1, 2, 3, 4)

# %%
band1 = dataset.read(1)

# %%
band1
# Out:
# array([[114, 105, 122, ..., 147, 148, 148],
#        [131, 130, 118, ..., 149, 148, 150],
#        [127, 136,  99, ..., 149, 150, 155],
#        ...,
#        [126, 140, 150, ...,  83, 101, 109],
#        [168, 135, 130, ...,  84,  93,  79],
#        [206, 196, 169, ..., 132, 115,  87]], dtype=uint8)

# %%
show(dataset.read(1))
# Out:
# <Axes: >
